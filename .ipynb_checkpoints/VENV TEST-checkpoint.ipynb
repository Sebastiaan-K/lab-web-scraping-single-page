# %%
# read the file of not hot songs

data = pd.read_csv('dataset.csv')
data = data.sample(3000)
display(data)
# Out:
#        Unnamed: 0                track_id  \
# 26687       26687  3FoHPS9RV347IHECud31Od
# 16002       16002  7JGgKHHDgJCJkQCQxyHHdl
# 64221       64221  7ccsKU0u0EB123rIg20ktB
# 34144       34144  2GxASwsYYNS8WPKri3dFSD
# 32048       32048  6FvZIDTCtmWC4KERBlLQ5f
# ...           ...                     ...
# 13217       13217  1Weoa6up0EPWrkK0J1WzQf
# 38066       38066  4IiuExPFijOGZnVxGsKWcc
# 9684         9684  58OPCce8rzYv2PF9uhpK1T
# 29707       29707  5KDeKHT9wILGR7w38RiEIe
# 61835       61835  4UB2EL1sNtI4CLfKSCvbwG
#
#                                     artists  \
# 26687  Frank Churchill;Larry Morey;Ed Plumb
# 16002              Bombay Jayashri;DJ Aftab
# 64221                       Ella Fitzgerald
# 34144                          James Taylor
# 32048                           Babasónicos
# ...                                     ...
# 13217                          Paul Johnson
# 38066      The White Stripes;The Glitch Mob
# 9684             Mato Seco;Nazireu Rupestre
# 29707                              Krewella
# 61835                      Chisato Moritaka
#
#                                      album_name  \
# 26687                                     Bambi
# 16002        Hindi Slowed Reverb Bollywood Lofi
# 64221                    Beste Weihnachtslieder
# 34144                   Christmas Playlist 2022
# 32048                            tardes tranqui
# ...                                         ...
# 13217                      The Groove I Have LP
# 38066  Seven Nation Army (The Glitch Mob Remix)
# 9684                          Seco e Ainda Vivo
# 29707                                     Alive
# 61835         ザ・シングルス 1987-1992 (2012 Remaster)
#
#                                               track_name  popularity  \
# 26687  It Could Even Happen to Flower - From "Bambi"/...          20
# 16002                                   Zara Zara - Lofi          54
# 64221                                 Frosty The Snowman           0
# 34144                                     Auld Lang Syne           0
# 32048                                Como Eran Las Cosas           0
# ...                                                  ...         ...
# 13217             I'm Gonna Dance Tonight - Original Mix          13
# 38066           Seven Nation Army - The Glitch Mob Remix          65
# 9684                                       Um Novo Lugar          43
# 29707                                              Alive          32
# 61835                  だいて - ラスベガス・ヴァージョン; 2012 Remaster          19
#
#        duration_ms  explicit  danceability  energy  ...  loudness  mode  \
# 26687       119506     False         0.378   0.111  ...   -20.042     1
# 16002       219437     False         0.608   0.638  ...    -6.008     0
# 64221       131733     False         0.579   0.502  ...    -7.570     1
# 34144       216146     False         0.510   0.262  ...   -10.906     1
# 32048       242520     False         0.696   0.448  ...    -9.099     1
# ...            ...       ...           ...     ...  ...       ...   ...
# 13217       294999     False         0.973   0.895  ...    -8.268     1
# 38066       257021     False         0.701   0.844  ...    -6.629     1
# 9684        428746     False         0.796   0.491  ...    -7.783     1
# 29707       290760     False         0.663   0.822  ...    -2.909     1
# 61835       300320     False         0.680   0.866  ...    -4.966     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 26687       0.0354      0.847000          0.002700    0.0921    0.510
# 16002       0.0292      0.581000          0.017200    0.4480    0.439
# 64221       0.0513      0.733000          0.000000    0.2810    0.836
# 34144       0.0330      0.776000          0.000137    0.1130    0.234
# 32048       0.0333      0.452000          0.000024    0.0904    0.569
# ...            ...           ...               ...       ...      ...
# 13217       0.4110      0.000711          0.268000    0.1190    0.380
# 38066       0.1330      0.152000          0.626000    0.1940    0.198
# 9684        0.0428      0.048300          0.000000    0.3460    0.888
# 29707       0.0557      0.004130          0.003180    0.2340    0.567
# 61835       0.0311      0.461000          0.000010    0.0851    0.935
#
#          tempo  time_signature    track_genre
# 26687  102.735               4         disney
# 16002  140.109               4      classical
# 64221   76.783               4           jazz
# 34144  119.736               3           folk
# 32048   95.004               4     electronic
# ...        ...             ...            ...
# 13217  132.011               4  chicago-house
# 38066  120.040               4         garage
# 9684   124.042               4         brazil
# 29707  128.002               4        dubstep
# 61835  129.959               4         j-idol
#
# [3000 rows x 21 columns]

# %%
import numpy as np
import pandas as pd
import sys
sys.path.insert(1, 'config.py')
from config import *
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
from time import sleep
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 6
#       4 sys.path.insert(1, 'config.py')
#       5 from config import *
# ----> 6 import spotipy
#       7 import json
#       8 from spotipy.oauth2 import SpotifyClientCredentials
#
# ModuleNotFoundError: No module named 'spotipy'

# %%
#import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
data2 = pd.read_csv('Hot100.csv')
display(data2)
# Out:
#                            Song                   Artist
# 0            Paint The Town Red                 Doja Cat
# 1                        Snooze                      SZA
# 2                  Cruel Summer             Taylor Swift
# 3                      Fast Car               Luke Combs
# 4                            3D  Jung Kook & Jack Harlow
# ..                          ...                      ...
# 95                 Long Journey                 Rod Wave
# 96  But I Got A Beer In My Hand               Luke Bryan
# 97                      Rubicon               Peso Pluma
# 98          East Side Of Sorrow               Zach Bryan
# 99               Where She Goes                Bad Bunny
#
# [100 rows x 2 columns]

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
# read the file of not hot songs
data = pd.read_csv('dataset.csv')
data = data.sample(3000, random_state=42)
display(data)
#read the hot100
data2 = pd.read_csv('Hot100.csv')
display(data2)
# making the Artist and Song columns have the same label for not hot songs dataframe
data = data.rename(columns={'artists': 'Artist', 'track_name': 'Song'})
data.head()
# identifying common songs based on track names
common_songs = data[data['Song'].isin(data2['Song'])]
display(common_songs)
# Drop those rows from data
common_songs = data[data['Song'].isin(data2['Song'])].index
data = data.drop(common_songs)
display(data)
# Out:
#         Unnamed: 0                track_id  \
# 113186      113186  6KwkVtXm8OUp2XffN5k7lY
# 42819        42819  2dp5I5MJ8bQQHDoFaNRFtX
# 59311        59311  5avw06usmFkFrPjX8NxC40
# 91368        91368  75hT0hvlESnDJstem0JgyR
# 61000        61000  4bY2oZGA5Br3pTE1Jd1IfY
# ...            ...                     ...
# 22552        22552  3yPQrLnNIthn4I5wQ51X26
# 74120        74120  0Cro1lolgliyLKxGptK6RZ
# 12321        12321  6kZfjIUmJqQAosGKyOcOIk
# 64492        64492  5vOVMNYDam6F6jtemqnNX2
# 11761        11761  5zqJlEJcn0EfnvAScH8swK
#
#                                    artists                         album_name  \
# 113186                    Hillsong Worship                      No Other Name
# 42819                         Internal Rot                     Grieving Birth
# 59311           Zhoobin Askarieh;Ali Sasha               Noise A Noise 20.4-1
# 91368                          Bryan Adams    All I Want For Christmas Is You
# 61000                           Nogizaka46                         バレッタ TypeD
# ...                                    ...                                ...
# 22552                             Soilwork                 Figure Number Five
# 74120                         Zeca Baleiro                           Top Hits
# 12321               Jacky Cheung;Anita Mui                               他在那裡
# 64492   Antônio Carlos Jobim;Frank Sinatra  christmas but not christmas songs
# 11761                          The Beatles         Yellow Submarine Songtrack
#
#                    track_name  popularity  duration_ms  explicit  \
# 113186          No Other Name          50       440247     False
# 42819          Failed Organum          11        93933     False
# 59311   Save the Trees, Pt. 1           0       213578     False
# 91368         Merry Christmas           0       151387     False
# 61000                   月の大きさ          57       236293     False
# ...                       ...         ...          ...       ...
# 22552        Distortion Sleep          55       225933     False
# 74120        Proibida Pra Mim          46       195000     False
# 12321       相愛很難 - 電影"男人四十"歌曲          52       223253     False
# 64492   The Girl From Ipanema           0       200360     False
# 11761    All You Need Is Love          53       226666     False
#
#         danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 113186         0.369   0.598  ...    -6.984     1       0.0304      0.005110
# 42819          0.171   0.997  ...    -3.586     1       0.1180      0.005210
# 59311          0.173   0.803  ...   -10.071     0       0.1440      0.613000
# 91368          0.683   0.511  ...    -5.598     1       0.0279      0.406000
# 61000          0.555   0.941  ...    -3.294     0       0.0481      0.484000
# ...              ...     ...  ...       ...   ...          ...           ...
# 22552          0.368   0.949  ...    -6.178     1       0.1410      0.000078
# 74120          0.650   0.361  ...   -10.614     1       0.0328      0.722000
# 12321          0.495   0.559  ...    -8.888     1       0.0470      0.613000
# 64492          0.541   0.321  ...   -14.418     1       0.0329      0.714000
# 11761          0.364   0.483  ...    -8.220     1       0.0317      0.281000
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 113186          0.000000    0.1760   0.0466  148.014               4
# 42819           0.801000    0.4200   0.0294  122.223               4
# 59311           0.001910    0.1950   0.0887   75.564               3
# 91368           0.000197    0.1110   0.5980  109.991               3
# 61000           0.000000    0.2660   0.8130   92.487               4
# ...                  ...       ...      ...      ...             ...
# 22552           0.004290    0.0341   0.3470  160.270               4
# 74120           0.000000    0.0970   0.5400  132.839               4
# 12321           0.000000    0.1410   0.3220  134.508               4
# 64492           0.003450    0.1010   0.5490  133.537               4
# 11761           0.000002    0.1130   0.7000  102.967               4
#
#         track_genre
# 113186  world-music
# 42819     grindcore
# 59311       iranian
# 91368          rock
# 61000        j-idol
# ...             ...
# 22552   death-metal
# 74120           mpb
# 12321      cantopop
# 64492          jazz
# 11761       british
#
# [3000 rows x 21 columns]
#                            Song                   Artist
# 0            Paint The Town Red                 Doja Cat
# 1                        Snooze                      SZA
# 2                  Cruel Summer             Taylor Swift
# 3                      Fast Car               Luke Combs
# 4                            3D  Jung Kook & Jack Harlow
# ..                          ...                      ...
# 95                 Long Journey                 Rod Wave
# 96  But I Got A Beer In My Hand               Luke Bryan
# 97                      Rubicon               Peso Pluma
# 98          East Side Of Sorrow               Zach Bryan
# 99               Where She Goes                Bad Bunny
#
# [100 rows x 2 columns]
#        Unnamed: 0                track_id        Artist  \
# 79596       79596  4XLlFjAwjDENyqYAkRbVuA  Smyang Piano
# 70000       70000  1Mut1YA6ZxKZ7F6MKsMSQu        JJ Lin
#
#                                               album_name          Song  \
# 79596                           Piano Collection, Vol. 1       Save Me
# 70000  Shang-Chi and The Legend of The Ten Rings: The...  Lose Control
#
#        popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# 79596          40       198138     False         0.427  0.0771  ...   -20.939
# 70000          55       254800     False         0.560  0.7500  ...    -5.885
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 79596     1       0.0468         0.987             0.853     0.119    0.184
# 70000     1       0.0816         0.223             0.427     0.204    0.279
#
#          tempo  time_signature  track_genre
# 79596  137.357               4        piano
# 70000  100.077               4     mandopop
#
# [2 rows x 21 columns]
#         Unnamed: 0                track_id  \
# 113186      113186  6KwkVtXm8OUp2XffN5k7lY
# 42819        42819  2dp5I5MJ8bQQHDoFaNRFtX
# 59311        59311  5avw06usmFkFrPjX8NxC40
# 91368        91368  75hT0hvlESnDJstem0JgyR
# 61000        61000  4bY2oZGA5Br3pTE1Jd1IfY
# ...            ...                     ...
# 22552        22552  3yPQrLnNIthn4I5wQ51X26
# 74120        74120  0Cro1lolgliyLKxGptK6RZ
# 12321        12321  6kZfjIUmJqQAosGKyOcOIk
# 64492        64492  5vOVMNYDam6F6jtemqnNX2
# 11761        11761  5zqJlEJcn0EfnvAScH8swK
#
#                                     Artist                         album_name  \
# 113186                    Hillsong Worship                      No Other Name
# 42819                         Internal Rot                     Grieving Birth
# 59311           Zhoobin Askarieh;Ali Sasha               Noise A Noise 20.4-1
# 91368                          Bryan Adams    All I Want For Christmas Is You
# 61000                           Nogizaka46                         バレッタ TypeD
# ...                                    ...                                ...
# 22552                             Soilwork                 Figure Number Five
# 74120                         Zeca Baleiro                           Top Hits
# 12321               Jacky Cheung;Anita Mui                               他在那裡
# 64492   Antônio Carlos Jobim;Frank Sinatra  christmas but not christmas songs
# 11761                          The Beatles         Yellow Submarine Songtrack
#
#                          Song  popularity  duration_ms  explicit  \
# 113186          No Other Name          50       440247     False
# 42819          Failed Organum          11        93933     False
# 59311   Save the Trees, Pt. 1           0       213578     False
# 91368         Merry Christmas           0       151387     False
# 61000                   月の大きさ          57       236293     False
# ...                       ...         ...          ...       ...
# 22552        Distortion Sleep          55       225933     False
# 74120        Proibida Pra Mim          46       195000     False
# 12321       相愛很難 - 電影"男人四十"歌曲          52       223253     False
# 64492   The Girl From Ipanema           0       200360     False
# 11761    All You Need Is Love          53       226666     False
#
#         danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 113186         0.369   0.598  ...    -6.984     1       0.0304      0.005110
# 42819          0.171   0.997  ...    -3.586     1       0.1180      0.005210
# 59311          0.173   0.803  ...   -10.071     0       0.1440      0.613000
# 91368          0.683   0.511  ...    -5.598     1       0.0279      0.406000
# 61000          0.555   0.941  ...    -3.294     0       0.0481      0.484000
# ...              ...     ...  ...       ...   ...          ...           ...
# 22552          0.368   0.949  ...    -6.178     1       0.1410      0.000078
# 74120          0.650   0.361  ...   -10.614     1       0.0328      0.722000
# 12321          0.495   0.559  ...    -8.888     1       0.0470      0.613000
# 64492          0.541   0.321  ...   -14.418     1       0.0329      0.714000
# 11761          0.364   0.483  ...    -8.220     1       0.0317      0.281000
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 113186          0.000000    0.1760   0.0466  148.014               4
# 42819           0.801000    0.4200   0.0294  122.223               4
# 59311           0.001910    0.1950   0.0887   75.564               3
# 91368           0.000197    0.1110   0.5980  109.991               3
# 61000           0.000000    0.2660   0.8130   92.487               4
# ...                  ...       ...      ...      ...             ...
# 22552           0.004290    0.0341   0.3470  160.270               4
# 74120           0.000000    0.0970   0.5400  132.839               4
# 12321           0.000000    0.1410   0.3220  134.508               4
# 64492           0.003450    0.1010   0.5490  133.537               4
# 11761           0.000002    0.1130   0.7000  102.967               4
#
#         track_genre
# 113186  world-music
# 42819     grindcore
# 59311       iranian
# 91368          rock
# 61000        j-idol
# ...             ...
# 22552   death-metal
# 74120           mpb
# 12321      cantopop
# 64492          jazz
# 11761       british
#
# [2998 rows x 21 columns]

# %%
# !writefile requirements.txt
numpy
pandas
matplotlib
# Out:
# 'writefile' is not recognized as an internal or external command,
# operable program or batch file.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 get_ipython().system('writefile requirements.txt')
# ----> 2 numpy
#       3 pandas
#       4 matplotlib
#
# NameError: name 'numpy' is not defined

# %%
pip freeze
# Out:
# anyio==4.0.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.2.3
# asttokens==2.4.0
# async-lru==2.0.4
# attrs==23.1.0
# Babel==2.12.1
# backcall==0.2.0
# beautifulsoup4==4.12.2
# bleach==6.0.0
# build==1.0.3
# certifi==2023.7.22
# cffi==1.15.1
# charset-normalizer==3.2.0
# click==8.1.7
# colorama==0.4.6
# comm==0.1.4
# contourpy==1.1.1
# cycler==0.12.0
# dacite==1.8.1
# debugpy==1.8.0
# decorator==5.1.1
# defusedxml==0.7.1
# docopt==0.6.2
# executing==1.2.0
# fastjsonschema==2.18.0
# fonttools==4.43.0
# fqdn==1.5.1
# htmlmin==0.1.12
# idna==3.4
# ImageHash==4.3.1
# importlib-resources==6.1.0
# ipykernel==6.25.2
# ipython==8.15.0
# ipython-genutils==0.2.0
# ipywidgets==8.1.1
# isoduration==20.11.0
# jedi==0.19.0
# Jinja2==3.1.2
# joblib==1.3.2
# json5==0.9.14
# jsonpointer==2.4
# jsonschema==4.19.1
# jsonschema-specifications==2023.7.1
# jupyter==1.0.0
# jupyter-console==6.6.3
# jupyter-events==0.7.0
# jupyter-lsp==2.2.0
# jupyter_client==8.3.1
# jupyter_core==5.3.2
# jupyter_server==2.7.3
# jupyter_server_terminals==0.4.4
# jupyterlab==4.0.6
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.9
# jupyterlab_server==2.25.0
# kiwisolver==1.4.5
# MarkupSafe==2.1.3
# matplotlib==3.7.3
# matplotlib-inline==0.1.6
# mistune==3.0.1
# multimethod==1.10
# nbclient==0.8.0
# nbconvert==7.8.0
# nbformat==5.9.2
# nest-asyncio==1.5.8
# networkx==3.1
# notebook==7.0.4
# notebook_shim==0.2.3
# numpy==1.23.5
# overrides==7.4.0
# packaging==23.1
# pandas==2.0.3
# pandocfilters==1.5.0
# parso==0.8.3
# patsy==0.5.3
# phik==0.12.3
# pickleshare==0.7.5
# Pillow==10.0.1
# pip-tools==7.3.0
# pipreqs==0.4.13
# platformdirs==3.10.0
# prometheus-client==0.17.1
# prompt-toolkit==3.0.39
# psutil==5.9.5
# pure-eval==0.2.2
# pycparser==2.21
# pydantic==1.10.13
# Pygments==2.16.1
# pyparsing==3.1.1
# pyproject_hooks==1.0.0
# python-dateutil==2.8.2
# python-json-logger==2.0.7
# pytz==2023.3.post1
# PyWavelets==1.4.1
# pywin32==306
# pywinpty==2.0.11
# PyYAML==6.0.1
# pyzmq==25.1.1
# qtconsole==5.4.4
# QtPy==2.4.0
# referencing==0.30.2
# requests==2.31.0
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rpds-py==0.10.3
# scikit-learn==1.3.1
# scipy==1.11.3
# seaborn==0.12.2
# Send2Trash==1.8.2
# six==1.16.0
# sniffio==1.3.0
# soupsieve==2.5
# stack-data==0.6.2
# statsmodels==0.14.0
# sweetviz==2.2.1
# tangled-up-in-unicode==0.2.0
# terminado==0.17.1
# threadpoolctl==3.2.0
# tinycss2==1.2.1
# tornado==6.3.3
# tqdm==4.66.1
# traitlets==5.10.1
# typeguard==2.13.3
# typing_extensions==4.8.0
# tzdata==2023.3
# uri-template==1.3.0
# urllib3==2.0.5
# visions==0.7.5
# wcwidth==0.2.6
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.6.3
# widgetsnbextension==4.0.9
# wordcloud==1.9.2
# yarg==0.1.9
# ydata-profiling==4.5.1
# Note: you may need to restart the kernel to use updated packages.
